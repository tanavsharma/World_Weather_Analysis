# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thanh hoa
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | vredendal
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 1 | lavrentiya
# Processing Record 10 of Set 1 | lumby
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | maunabo
# Processing Record 13 of Set 1 | phan thiet
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | port-gentil
# Processing Record 19 of Set 1 | delmas
# Processing Record 20 of Set 1 | lakes entrance
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | ponta delgada
# Processing Record 23 of Set 1 | narovchat
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | nicoya
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | coquimbo
# Processing Record 28 of Set 1 | iracoubo
# Processing Record 29 of Set 1 | kavos
# Processing Record 30 of Set 1 | quelimane
# Processing Record 31 of Set 1 | jacqueville
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | lhokseumawe
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | colorado
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | samarkand
# Processing Record 42 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 1 | kloulklubed
# Processing Record 47 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | williamsport
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | acapulco
# Processing Record 2 of Set 2 | sorland
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 2 | kongolo
# Processing Record 7 of Set 2 | batagay
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | bereda
# Processing Record 10 of Set 2 | sept-iles
# Processing Record 11 of Set 2 | luanda
# Processing Record 12 of Set 2 | golyshmanovo
# Processing Record 13 of Set 2 | zhaoyuan
# Processing Record 14 of Set 2 | port blair
# Processing Record 15 of Set 2 | nyurba
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | buraydah
# Processing Record 18 of Set 2 | avera
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | tapia
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | boende
# Processing Record 25 of Set 2 | roma
# Processing Record 26 of Set 2 | deputatskiy
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | chumikan
# Processing Record 30 of Set 2 | hualmay
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | lalmohan
# Processing Record 33 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | buin
# Processing Record 37 of Set 2 | faya
# Processing Record 38 of Set 2 | shiojiri
# Processing Record 39 of Set 2 | longyearbyen
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | saint-joseph
# Processing Record 44 of Set 2 | newport
# Processing Record 45 of Set 2 | yantal
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | honningsvag
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | am timan
# Processing Record 1 of Set 3 | waipawa
# Processing Record 2 of Set 3 | chesma
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | rocha
# Processing Record 5 of Set 3 | pozo colorado
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | formosa
# Processing Record 9 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | ossora
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | college
# Processing Record 16 of Set 3 | ambilobe
# Processing Record 17 of Set 3 | nandyal
# Processing Record 18 of Set 3 | batemans bay
# Processing Record 19 of Set 3 | pidhorodne
# Processing Record 20 of Set 3 | punta arenas
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | gbarnga
# Processing Record 23 of Set 3 | salaga
# Processing Record 24 of Set 3 | saint-augustin
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | yumen
# Processing Record 28 of Set 3 | atocha
# Processing Record 29 of Set 3 | bairiki
# Processing Record 30 of Set 3 | zhezkazgan
# Processing Record 31 of Set 3 | chegdomyn
# Processing Record 32 of Set 3 | yashan
# Processing Record 33 of Set 3 | develi
# Processing Record 34 of Set 3 | zhigansk
# Processing Record 35 of Set 3 | baherden
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | bilibino
# Processing Record 38 of Set 3 | moron
# Processing Record 39 of Set 3 | batagay-alyta
# Processing Record 40 of Set 3 | ardesen
# Processing Record 41 of Set 3 | burnie
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | zhangjiakou
# Processing Record 44 of Set 3 | balao
# Processing Record 45 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | vila velha
# Processing Record 50 of Set 3 | belmonte
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | standerton
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | qaqortoq
# Processing Record 8 of Set 4 | pevek
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | lazurne
# Processing Record 12 of Set 4 | codrington
# Processing Record 13 of Set 4 | chita
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | bullerup
# Processing Record 16 of Set 4 | roald
# Processing Record 17 of Set 4 | anamur
# Processing Record 18 of Set 4 | eskisehir
# Processing Record 19 of Set 4 | kodinsk
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | la palma
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | madimba
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | poya
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | srednebelaya
# Processing Record 28 of Set 4 | maragogi
# Processing Record 29 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 4 | sijunjung
# Processing Record 31 of Set 4 | new glasgow
# Processing Record 32 of Set 4 | butaritari
# Processing Record 33 of Set 4 | meulaboh
# Processing Record 34 of Set 4 | dunedin
# Processing Record 35 of Set 4 | arman
# Processing Record 36 of Set 4 | tiarei
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | micheweni
# Processing Record 39 of Set 4 | hervey bay
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | la union
# Processing Record 44 of Set 4 | yellowknife
# Processing Record 45 of Set 4 | saint anthony
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | angoche
# Processing Record 48 of Set 4 | santa rosa
# Processing Record 49 of Set 4 | champerico
# Processing Record 50 of Set 4 | padang
# Processing Record 1 of Set 5 | axim
# Processing Record 2 of Set 5 | udachnyy
# Processing Record 3 of Set 5 | yoichi
# Processing Record 4 of Set 5 | bredasdorp
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | iqaluit
# Processing Record 7 of Set 5 | kirkwood
# Processing Record 8 of Set 5 | puerto escondido
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | yar-sale
# Processing Record 11 of Set 5 | nemuro
# Processing Record 12 of Set 5 | balad
# Processing Record 13 of Set 5 | port lincoln
# Processing Record 14 of Set 5 | weinan
# Processing Record 15 of Set 5 | cochrane
# Processing Record 16 of Set 5 | caravelas
# Processing Record 17 of Set 5 | pili
# Processing Record 18 of Set 5 | te anau
# Processing Record 19 of Set 5 | bengkulu
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | mananjary
# Processing Record 23 of Set 5 | kisangani
# Processing Record 24 of Set 5 | ancud
# Processing Record 25 of Set 5 | lebedinyy
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | nokaneng
# Processing Record 28 of Set 5 | tuatapere
# Processing Record 29 of Set 5 | gold coast
# Processing Record 30 of Set 5 | cozumel
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | dargaville
# Processing Record 33 of Set 5 | tir pol
# City not found. Skipping...
# Processing Record 34 of Set 5 | kibaya
# Processing Record 35 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | tuljapur
# Processing Record 38 of Set 5 | oxapampa
# Processing Record 39 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 5 | mount isa
# Processing Record 41 of Set 5 | margate
# Processing Record 42 of Set 5 | srednekolymsk
# Processing Record 43 of Set 5 | mala
# Processing Record 44 of Set 5 | grindavik
# Processing Record 45 of Set 5 | vadlapudi
# Processing Record 46 of Set 5 | antalaha
# Processing Record 47 of Set 5 | constitucion
# Processing Record 48 of Set 5 | comodoro rivadavia
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | brae
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | brufut
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | artigas
# Processing Record 5 of Set 6 | anshun
# Processing Record 6 of Set 6 | cairns
# Processing Record 7 of Set 6 | cam ranh
# Processing Record 8 of Set 6 | touros
# Processing Record 9 of Set 6 | mahibadhoo
# Processing Record 10 of Set 6 | debno
# Processing Record 11 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 6 | arraial do cabo
# Processing Record 13 of Set 6 | cayenne
# Processing Record 14 of Set 6 | port augusta
# Processing Record 15 of Set 6 | ereymentau
# Processing Record 16 of Set 6 | san isidro
# Processing Record 17 of Set 6 | kahului
# Processing Record 18 of Set 6 | pangai
# Processing Record 19 of Set 6 | dryden
# Processing Record 20 of Set 6 | basoko
# Processing Record 21 of Set 6 | sebinkarahisar
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | san antonio
# Processing Record 24 of Set 6 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 25 of Set 6 | mandalgovi
# Processing Record 26 of Set 6 | baft
# Processing Record 27 of Set 6 | baykit
# Processing Record 28 of Set 6 | bubaque
# Processing Record 29 of Set 6 | pitimbu
# Processing Record 30 of Set 6 | nueve de julio
# Processing Record 31 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 6 | kendari
# Processing Record 33 of Set 6 | mehamn
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | nipawin
# Processing Record 36 of Set 6 | petatlan
# Processing Record 37 of Set 6 | nantucket
# Processing Record 38 of Set 6 | araguacu
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | agva
# City not found. Skipping...
# Processing Record 41 of Set 6 | svetlyy
# Processing Record 42 of Set 6 | havelock
# Processing Record 43 of Set 6 | itanhem
# Processing Record 44 of Set 6 | kamenka
# Processing Record 45 of Set 6 | hovd
# Processing Record 46 of Set 6 | namibe
# Processing Record 47 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 6 | dubbo
# Processing Record 49 of Set 6 | naze
# Processing Record 50 of Set 6 | abu samrah
# Processing Record 1 of Set 7 | priekule
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | walvis bay
# Processing Record 4 of Set 7 | hamilton
# Processing Record 5 of Set 7 | arlit
# Processing Record 6 of Set 7 | sri aman
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | port hueneme
# Processing Record 9 of Set 7 | atambua
# Processing Record 10 of Set 7 | sinnamary
# Processing Record 11 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 7 | castrillon
# Processing Record 13 of Set 7 | babu
# Processing Record 14 of Set 7 | berbera
# Processing Record 15 of Set 7 | poronaysk
# Processing Record 16 of Set 7 | launceston
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | evensk
# Processing Record 19 of Set 7 | ashland
# Processing Record 20 of Set 7 | vanimo
# Processing Record 21 of Set 7 | camacha
# Processing Record 22 of Set 7 | radhanpur
# Processing Record 23 of Set 7 | zyryanka
# Processing Record 24 of Set 7 | shelburne
# Processing Record 25 of Set 7 | calama
# Processing Record 26 of Set 7 | cidreira
# Processing Record 27 of Set 7 | comonfort
# Processing Record 28 of Set 7 | jinja
# Processing Record 29 of Set 7 | kieta
# Processing Record 30 of Set 7 | ambulu
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 7 | del rio
# Processing Record 34 of Set 7 | poum
# Processing Record 35 of Set 7 | sao gabriel da cachoeira
# Processing Record 36 of Set 7 | vila
# Processing Record 37 of Set 7 | duzici
# City not found. Skipping...
# Processing Record 38 of Set 7 | tilichiki
# Processing Record 39 of Set 7 | nishihara
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | trapani
# Processing Record 42 of Set 7 | pangnirtung
# Processing Record 43 of Set 7 | kinsale
# Processing Record 44 of Set 7 | navrongo
# Processing Record 45 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 7 | emerald
# Processing Record 47 of Set 7 | sao joao da barra
# Processing Record 48 of Set 7 | hollister
# Processing Record 49 of Set 7 | setermoen
# Processing Record 50 of Set 7 | impfondo
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | oranjestad
# Processing Record 3 of Set 8 | ginda
# Processing Record 4 of Set 8 | cockburn town
# Processing Record 5 of Set 8 | chara
# Processing Record 6 of Set 8 | klaksvik
# Processing Record 7 of Set 8 | mikhaylovka
# Processing Record 8 of Set 8 | jacareacanga
# Processing Record 9 of Set 8 | niquelandia
# Processing Record 10 of Set 8 | gravdal
# Processing Record 11 of Set 8 | morgan city
# Processing Record 12 of Set 8 | leningradskiy
# Processing Record 13 of Set 8 | dunmore town
# Processing Record 14 of Set 8 | todos santos
# Processing Record 15 of Set 8 | kjollefjord
# Processing Record 16 of Set 8 | ahipara
# Processing Record 17 of Set 8 | pacific grove
# Processing Record 18 of Set 8 | sioux lookout
# Processing Record 19 of Set 8 | nelson bay
# Processing Record 20 of Set 8 | ulaanbaatar
# Processing Record 21 of Set 8 | mahebourg
# Processing Record 22 of Set 8 | strabychovo
# Processing Record 23 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | cabo san lucas
# Processing Record 25 of Set 8 | pasni
# Processing Record 26 of Set 8 | chivasso
# Processing Record 27 of Set 8 | santa isabel do rio negro
# Processing Record 28 of Set 8 | thilogne
# City not found. Skipping...
# Processing Record 29 of Set 8 | hofn
# Processing Record 30 of Set 8 | cabedelo
# Processing Record 31 of Set 8 | brigantine
# Processing Record 32 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 8 | nome
# Processing Record 34 of Set 8 | severo-kurilsk
# Processing Record 35 of Set 8 | haines junction
# Processing Record 36 of Set 8 | beloha
# Processing Record 37 of Set 8 | wasilla
# Processing Record 38 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 8 | ngunguru
# Processing Record 40 of Set 8 | tiksi
# Processing Record 41 of Set 8 | muriwai beach
# Processing Record 42 of Set 8 | gandajika
# Processing Record 43 of Set 8 | calbuco
# Processing Record 44 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 8 | lyubech
# Processing Record 46 of Set 8 | kota tinggi
# Processing Record 47 of Set 8 | belyy yar
# Processing Record 48 of Set 8 | salinopolis
# Processing Record 49 of Set 8 | perdoes
# Processing Record 50 of Set 8 | mramor
# Processing Record 1 of Set 9 | gamba
# Processing Record 2 of Set 9 | benavente
# Processing Record 3 of Set 9 | lata
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | wageningen
# Processing Record 6 of Set 9 | wawa
# Processing Record 7 of Set 9 | pombas
# Processing Record 8 of Set 9 | tourlaville
# Processing Record 9 of Set 9 | pangkalanbuun
# Processing Record 10 of Set 9 | necochea
# Processing Record 11 of Set 9 | maniitsoq
# Processing Record 12 of Set 9 | winnemucca
# Processing Record 13 of Set 9 | mangrol
# Processing Record 14 of Set 9 | vanavara
# Processing Record 15 of Set 9 | half moon bay
# Processing Record 16 of Set 9 | vestmannaeyjar
# Processing Record 17 of Set 9 | guerrero negro
# Processing Record 18 of Set 9 | saskylakh
# Processing Record 19 of Set 9 | gerash
# Processing Record 20 of Set 9 | tessalit
# Processing Record 21 of Set 9 | sao jose da coroa grande
# Processing Record 22 of Set 9 | salmas
# Processing Record 23 of Set 9 | chiang rai
# Processing Record 24 of Set 9 | kununurra
# Processing Record 25 of Set 9 | flinders
# Processing Record 26 of Set 9 | acarau
# Processing Record 27 of Set 9 | lufkin
# Processing Record 28 of Set 9 | ixtapa
# Processing Record 29 of Set 9 | monroe
# Processing Record 30 of Set 9 | lasa
# Processing Record 31 of Set 9 | oktyabrskoye
# Processing Record 32 of Set 9 | dharchula
# Processing Record 33 of Set 9 | omvriaki
# Processing Record 34 of Set 9 | skegness
# Processing Record 35 of Set 9 | taltal
# Processing Record 36 of Set 9 | lagos
# Processing Record 37 of Set 9 | laguna
# Processing Record 38 of Set 9 | cestas
# Processing Record 39 of Set 9 | kabare
# Processing Record 40 of Set 9 | moerai
# Processing Record 41 of Set 9 | rawson
# Processing Record 42 of Set 9 | hanyang
# Processing Record 43 of Set 9 | kumla
# Processing Record 44 of Set 9 | oum hadjer
# Processing Record 45 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 46 of Set 9 | tocopilla
# Processing Record 47 of Set 9 | kingston
# Processing Record 48 of Set 9 | san blas
# Processing Record 49 of Set 9 | san vicente
# Processing Record 50 of Set 9 | carutapera
# Processing Record 1 of Set 10 | partizanskoye
# Processing Record 2 of Set 10 | berlevag
# Processing Record 3 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 10 | marawi
# Processing Record 5 of Set 10 | porto santo
# Processing Record 6 of Set 10 | chicama
# Processing Record 7 of Set 10 | hambantota
# Processing Record 8 of Set 10 | teguldet
# Processing Record 9 of Set 10 | aswan
# Processing Record 10 of Set 10 | termini imerese
# Processing Record 11 of Set 10 | uyuni
# Processing Record 12 of Set 10 | chama
# Processing Record 13 of Set 10 | la asuncion
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | svetlogorsk
# Processing Record 16 of Set 10 | luena
# Processing Record 17 of Set 10 | malanje
# Processing Record 18 of Set 10 | takoradi
# Processing Record 19 of Set 10 | kargopol
# Processing Record 20 of Set 10 | vincennes
# Processing Record 21 of Set 10 | aykhal
# Processing Record 22 of Set 10 | darhan
# Processing Record 23 of Set 10 | channel-port aux basques
# Processing Record 24 of Set 10 | merauke
# Processing Record 25 of Set 10 | puerto del rosario
# Processing Record 26 of Set 10 | old orchard beach
# Processing Record 27 of Set 10 | ilulissat
# Processing Record 28 of Set 10 | la ronge
# Processing Record 29 of Set 10 | santa fe
# Processing Record 30 of Set 10 | yarada
# Processing Record 31 of Set 10 | charagua
# Processing Record 32 of Set 10 | san juan
# Processing Record 33 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 10 | abu dhabi
# Processing Record 35 of Set 10 | nocupetaro
# Processing Record 36 of Set 10 | oriximina
# Processing Record 37 of Set 10 | leh
# Processing Record 38 of Set 10 | kenora
# Processing Record 39 of Set 10 | richards bay
# Processing Record 40 of Set 10 | keti bandar
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | nuevitas
# Processing Record 43 of Set 10 | bilma
# Processing Record 44 of Set 10 | jiuquan
# Processing Record 45 of Set 10 | gayny
# Processing Record 46 of Set 10 | vavuniya
# Processing Record 47 of Set 10 | zhangye
# Processing Record 48 of Set 10 | cumana
# Processing Record 49 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 10 | wajir
# Processing Record 1 of Set 11 | sunrise manor
# Processing Record 2 of Set 11 | ballina
# Processing Record 3 of Set 11 | alexandria
# Processing Record 4 of Set 11 | wyndham
# Processing Record 5 of Set 11 | khani
# Processing Record 6 of Set 11 | beshpagir
# Processing Record 7 of Set 11 | puerto pinasco
# City not found. Skipping...
# Processing Record 8 of Set 11 | swan river
# Processing Record 9 of Set 11 | noisy-le-sec
# Processing Record 10 of Set 11 | paamiut
# Processing Record 11 of Set 11 | goderich
# Processing Record 12 of Set 11 | southbridge
# Processing Record 13 of Set 11 | salto de agua
# Processing Record 14 of Set 11 | oranjemund
# Processing Record 15 of Set 11 | indiana
# Processing Record 16 of Set 11 | muisne
# Processing Record 17 of Set 11 | behbahan
# Processing Record 18 of Set 11 | alice springs
# Processing Record 19 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | salalah
# Processing Record 22 of Set 11 | yelizovo
# Processing Record 23 of Set 11 | inhambane
# Processing Record 24 of Set 11 | khandbari
# Processing Record 25 of Set 11 | rio gallegos
# Processing Record 26 of Set 11 | labuhan
# Processing Record 27 of Set 11 | milford
# Processing Record 28 of Set 11 | katangli
# Processing Record 29 of Set 11 | solnechnyy
# Processing Record 30 of Set 11 | bosaso
# Processing Record 31 of Set 11 | lovozero
# Processing Record 32 of Set 11 | beringovskiy
# Processing Record 33 of Set 11 | saint-pierre
# Processing Record 34 of Set 11 | ler
# Processing Record 35 of Set 11 | tromso
# Processing Record 36 of Set 11 | port hardy
# Processing Record 37 of Set 11 | sampit
# Processing Record 38 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 11 | kumher
# Processing Record 40 of Set 11 | nieuw amsterdam
# Processing Record 41 of Set 11 | sambava
# Processing Record 42 of Set 11 | altamont
# Processing Record 43 of Set 11 | high level
# Processing Record 44 of Set 11 | egvekinot
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | flin flon
# Processing Record 47 of Set 11 | kemi
# Processing Record 48 of Set 11 | vilhena
# Processing Record 49 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 11 | brenham
# Processing Record 1 of Set 12 | san quintin
# Processing Record 2 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 3 of Set 12 | belaya gora
# Processing Record 4 of Set 12 | boa vista
# Processing Record 5 of Set 12 | martapura
# Processing Record 6 of Set 12 | paramonga
# Processing Record 7 of Set 12 | rehoboth
# Processing Record 8 of Set 12 | remscheid
# Processing Record 9 of Set 12 | kitimat
# Processing Record 10 of Set 12 | severnoye
# Processing Record 11 of Set 12 | hammerfest
# Processing Record 12 of Set 12 | teavaro
# Processing Record 13 of Set 12 | paita
# Processing Record 14 of Set 12 | mao
# Processing Record 15 of Set 12 | mahon
# Processing Record 16 of Set 12 | ilhabela
# Processing Record 17 of Set 12 | lorengau
# Processing Record 18 of Set 12 | bowen
# Processing Record 19 of Set 12 | houston
# Processing Record 20 of Set 12 | tezu
# Processing Record 21 of Set 12 | madang
# Processing Record 22 of Set 12 | clermont
# Processing Record 23 of Set 12 | hue
# Processing Record 24 of Set 12 | ilebo
# Processing Record 25 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 26 of Set 12 | san jose de guanipa
# Processing Record 27 of Set 12 | razole
# Processing Record 28 of Set 12 | vitrolles
# Processing Record 29 of Set 12 | mentakab
# Processing Record 30 of Set 12 | kanigoro
# Processing Record 31 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 12 | saint andrews
# Processing Record 33 of Set 12 | gazanjyk
# Processing Record 34 of Set 12 | tres picos
# Processing Record 35 of Set 12 | normandin
# Processing Record 36 of Set 12 | teguise
# Processing Record 37 of Set 12 | seymchan
# Processing Record 38 of Set 12 | garissa
# Processing Record 39 of Set 12 | duliagaon
# Processing Record 40 of Set 12 | shubarshi
# Processing Record 41 of Set 12 | reefton
# City not found. Skipping...
# Processing Record 42 of Set 12 | tual
# Processing Record 43 of Set 12 | harper
# Processing Record 44 of Set 12 | atasu
# Processing Record 45 of Set 12 | provost
# Processing Record 46 of Set 12 | dukat
# Processing Record 47 of Set 12 | dingle
# Processing Record 48 of Set 12 | jensen beach
# Processing Record 49 of Set 12 | banda aceh
# Processing Record 50 of Set 12 | prince rupert
# Processing Record 1 of Set 13 | beinamar
# Processing Record 2 of Set 13 | costa rica
# Processing Record 3 of Set 13 | klyuchi
# Processing Record 4 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 13 | tateyama
# Processing Record 6 of Set 13 | karratha
# Processing Record 7 of Set 13 | ketchikan
# Processing Record 8 of Set 13 | flagstaff
# Processing Record 9 of Set 13 | mayya
# Processing Record 10 of Set 13 | kihei
# Processing Record 11 of Set 13 | novokruchininskiy
# Processing Record 12 of Set 13 | porto walter
# Processing Record 13 of Set 13 | jackson
# Processing Record 14 of Set 13 | bairnsdale
# Processing Record 15 of Set 13 | tucumcari
# Processing Record 16 of Set 13 | christchurch
# Processing Record 17 of Set 13 | rabo de peixe
# Processing Record 18 of Set 13 | jumla
# Processing Record 19 of Set 13 | ribeira brava
# Processing Record 20 of Set 13 | mendoza
# Processing Record 21 of Set 13 | lautaro
# Processing Record 22 of Set 13 | taoudenni
# Processing Record 23 of Set 13 | phirangipuram
# Processing Record 24 of Set 13 | natori
# Processing Record 25 of Set 13 | serebryansk
# Processing Record 26 of Set 13 | alyangula
# Processing Record 27 of Set 13 | yerbogachen
# Processing Record 28 of Set 13 | baoshan
# Processing Record 29 of Set 13 | parrita
# Processing Record 30 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 31 of Set 13 | pangoa
# Processing Record 32 of Set 13 | viedma
# Processing Record 33 of Set 13 | chincholi
# Processing Record 34 of Set 13 | rio cuarto
# Processing Record 35 of Set 13 | maine-soroa
# Processing Record 36 of Set 13 | kaeo
# Processing Record 37 of Set 13 | san andres
# Processing Record 38 of Set 13 | lompoc
# Processing Record 39 of Set 13 | cowra
# Processing Record 40 of Set 13 | russell
# Processing Record 41 of Set 13 | troitsko-pechorsk
# Processing Record 42 of Set 13 | cabo rojo
# Processing Record 43 of Set 13 | yima
# Processing Record 44 of Set 13 | inongo
# Processing Record 45 of Set 13 | nizwa
# Processing Record 46 of Set 13 | baker city
# Processing Record 47 of Set 13 | jacobina
# Processing Record 48 of Set 13 | palana
# Processing Record 49 of Set 13 | rumonge
# Processing Record 50 of Set 13 | zaozerne
# Processing Record 1 of Set 14 | dali
# Processing Record 2 of Set 14 | jacksonville
# Processing Record 3 of Set 14 | nouadhibou
# Processing Record 4 of Set 14 | khash
# Processing Record 5 of Set 14 | koslan
# Processing Record 6 of Set 14 | riohacha
# Processing Record 7 of Set 14 | bakchar
# Processing Record 8 of Set 14 | homestead
# Processing Record 9 of Set 14 | komatipoort
# Processing Record 10 of Set 14 | yeniseysk
# Processing Record 11 of Set 14 | korla
# Processing Record 12 of Set 14 | tegal
# Processing Record 13 of Set 14 | jawhar
# Processing Record 14 of Set 14 | kurchum
# Processing Record 15 of Set 14 | hearst
# Processing Record 16 of Set 14 | sistranda
# Processing Record 17 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 14 | el alto
# Processing Record 19 of Set 14 | novikovo
# Processing Record 20 of Set 14 | batetskiy
# Processing Record 21 of Set 14 | shimoda
# Processing Record 22 of Set 14 | kerema
# Processing Record 23 of Set 14 | embonas
# Processing Record 24 of Set 14 | praia
# Processing Record 25 of Set 14 | durusu
# Processing Record 26 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 14 | pontianak
# Processing Record 28 of Set 14 | tambopata
# Processing Record 29 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 14 | madison
# Processing Record 31 of Set 14 | ziarat
# Processing Record 32 of Set 14 | kudahuvadhoo
# Processing Record 33 of Set 14 | birjand
# Processing Record 34 of Set 14 | ocos
# Processing Record 35 of Set 14 | asheboro
# Processing Record 36 of Set 14 | rivers
# Processing Record 37 of Set 14 | morococha
# Processing Record 38 of Set 14 | birobidzhan
# Processing Record 39 of Set 14 | harur
# Processing Record 40 of Set 14 | agadez
# Processing Record 41 of Set 14 | savinka
# Processing Record 42 of Set 14 | kenai
# Processing Record 43 of Set 14 | ko samui
# Processing Record 44 of Set 14 | andreapol
# Processing Record 45 of Set 14 | noboribetsu
# Processing Record 46 of Set 14 | otradnoye
# Processing Record 47 of Set 14 | vaitape
# Processing Record 48 of Set 14 | atbasar
# Processing Record 49 of Set 14 | mecca
# Processing Record 50 of Set 14 | dagana
# Processing Record 1 of Set 15 | laguna de perlas
# Processing Record 2 of Set 15 | chlorakas
# Processing Record 3 of Set 15 | ostrovnoy
# Processing Record 4 of Set 15 | turayf
# Processing Record 5 of Set 15 | puerto rico
# Processing Record 6 of Set 15 | traverse city
# Processing Record 7 of Set 15 | mkushi
# Processing Record 8 of Set 15 | clarence town
# Processing Record 9 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 15 | pemangkat
# Processing Record 11 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 15 | dillon
# Processing Record 13 of Set 15 | xam nua
# Processing Record 14 of Set 15 | kawalu
# Processing Record 15 of Set 15 | verkhnevilyuysk
# Processing Record 16 of Set 15 | ures
# Processing Record 17 of Set 15 | rincon
# Processing Record 18 of Set 15 | maldonado
# Processing Record 19 of Set 15 | pentecoste
# Processing Record 20 of Set 15 | kamina
# Processing Record 21 of Set 15 | wenling
# Processing Record 22 of Set 15 | mareeba
# Processing Record 23 of Set 15 | dire
# Processing Record 24 of Set 15 | tambovka
# Processing Record 25 of Set 15 | moroni
# Processing Record 26 of Set 15 | pauini
# Processing Record 27 of Set 15 | camabatela
# Processing Record 28 of Set 15 | richmond
# Processing Record 29 of Set 15 | siocon
# Processing Record 30 of Set 15 | turan
# Processing Record 31 of Set 15 | benghazi
# Processing Record 32 of Set 15 | canutama
# Processing Record 33 of Set 15 | eyl
# Processing Record 34 of Set 15 | prince george
# Processing Record 35 of Set 15 | itarsi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Thanh Hoa      VN  19.8000  105.7667     69.78        71         100
# 1            Bluff      NZ -46.6000  168.3333     55.80        90          97
# 2           Albany      US  42.6001  -73.9662     71.64        91          67
# 3           Barrow      US  71.2906 -156.7887     15.82        79         100
# 4         Hermanus      ZA -34.4187   19.2345     76.53        36           3
# ..             ...     ...      ...       ...       ...       ...         ...
# 675       Benghazi      LY  32.1167   20.0667     74.82        39           0
# 676       Canutama      BR  -6.5339  -64.3831     76.28        97         100
# 677            Eyl      SO   7.9803   49.8164     86.22        64          73
# 678  Prince George      CA  53.9166 -122.7530     47.62        93          20
# 679         Itarsi      IN  22.6167   77.7500     99.41        10           0
#
#      Wind Speed   Current Description
# 0          6.02       overcast clouds
# 1         13.85       overcast clouds
# 2          4.90         broken clouds
# 3         16.11            light snow
# 4          2.95             clear sky
# ..          ...                   ...
# 675        8.70             clear sky
# 676        2.89  heavy intensity rain
# 677       27.47         broken clouds
# 678        2.30            few clouds
# 679        7.29             clear sky
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
